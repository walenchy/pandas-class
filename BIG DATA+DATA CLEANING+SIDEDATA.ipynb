# %% [markdown]
# # EXTRACT ZIP FILE

# %%
import pandas as pd

# %% [markdown]
# import zipfile,  os
# from pathlib import path
# path = Path.home()
# BirminghamFile = zipfile.ZipFile(path,'Birmingham.zip')
# BirminghamFile.extractall()
# BirminghamFile.close()

# %% [markdown]
# # STEP 1 - Data collection

# %% [markdown]
# # step 2: Exploring the data in general and understanding each columns and rows

# %% [markdown]
# # Step 3: Looking at the business question asked which Quater has Birmingham the highest Social
#   #  Deprivation from Jan 2015: Jan 2019

# %% [markdown]
# ## Findings , we found out the Social Deprivation Dataset had no Date Column but within the context of the questionto look at the highest quartersso, solution was to bring in the Birmingham Data set and compare them with social Deprivation Datasetto find a code in columnThe desire result is to have one table with both 'LSOA' AND 'DATE'

# %% [markdown]
# ## Applying Data Engineering Technique to bring the Data into Shape

# %% [markdown]
# # Step 1 - import module

# %% [markdown]
# # Step 2 - read the Domain_of_ Deprivation.xlsx into jupyter Notebook and specify the name of the sheet you want

# %%
Domains_of_Deprivation = pd.read_excel('File_2_-_IoD2019_Domains_of_Deprivation.xlsx',sheet_name='IoD2019 Domains')
Domains_of_Deprivation.head(3)#checkin the first 3 rows
# Out:
#   LSOA code (2011)     LSOA name (2011) Local Authority District code (2019)  \
# 0        E01000001  City of London 001A                            E09000001
# 1        E01000002  City of London 001B                            E09000001
# 2        E01000003  City of London 001C                            E09000001
#
#   Local Authority District name (2019)  \
# 0                       City of London
# 1                       City of London
# 2                       City of London
#
#    Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)  \
# 0                                              29199
# 1                                              30379
# 2                                              14915
#
#    Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  9
# 1                                                 10
# 2                                                  5
#
#    Income Rank (where 1 is most deprived)  \
# 0                                   32831
# 1                                   29901
# 2                                   18510
#
#    Income Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
# 2                                                  6
#
#    Employment Rank (where 1 is most deprived)  \
# 0                                       32742
# 1                                       31190
# 2                                       15103
#
#    Employment Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
# 2                                                  5
#
#    Education, Skills and Training Rank (where 1 is most deprived)  \
# 0                                              32842
# 1                                              32832
# 2                                              26386
#
#    Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
# 2                                                  9
#
#    Health Deprivation and Disability Rank (where 1 is most deprived)  \
# 0                                              32113
# 1                                              29705
# 2                                              17600
#
#    Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
# 2                                                  6
#
#    Crime Rank (where 1 is most deprived)  \
# 0                                  32662
# 1                                  32789
# 2                                  29363
#
#    Crime Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
# 2                                                  9
#
#    Barriers to Housing and Services Rank (where 1 is most deprived)  \
# 0                                               7319
# 1                                              11707
# 2                                               2157
#
#    Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  3
# 1                                                  4
# 2                                                  1
#
#    Living Environment Rank (where 1 is most deprived)  \
# 0                                               7789
# 1                                              13070
# 2                                               4092
#
#    Living Environment Decile (where 1 is most deprived 10% of LSOAs)
# 0                                                  3
# 1                                                  4
# 2                                                  2

# %%
Domains_of_Deprivation.shape
# Out:
# (32844, 20)

# %% [markdown]
# # Step -5 Check the Domains_of_Deprivation columns name

# %%
Domains_of_Deprivation.columns
# Out:
# Index(['LSOA code (2011)', 'LSOA name (2011)',
#        'Local Authority District code (2019)',
#        'Local Authority District name (2019)',
#        'Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)',
#        'Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)',
#        'Income Rank (where 1 is most deprived)',
#        'Income Decile (where 1 is most deprived 10% of LSOAs)',
#        'Employment Rank (where 1 is most deprived)',
#        'Employment Decile (where 1 is most deprived 10% of LSOAs)',
#        'Education, Skills and Training Rank (where 1 is most deprived)',
#        'Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)',
#        'Health Deprivation and Disability Rank (where 1 is most deprived)',
#        'Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)',
#        'Crime Rank (where 1 is most deprived)',
#        'Crime Decile (where 1 is most deprived 10% of LSOAs)',
#        'Barriers to Housing and Services Rank (where 1 is most deprived)',
#        'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)',
#        'Living Environment Rank (where 1 is most deprived)',
#        'Living Environment Decile (where 1 is most deprived 10% of LSOAs)'],
#       dtype='object')

# %%
del Domains_of_Deprivation[ 'Local Authority District code (2019)']
del Domains_of_Deprivation[ 'Local Authority District name (2019)']

# %%
Domains_of_Deprivation.columns
# Out:
# Index(['LSOA code (2011)', 'LSOA name (2011)',
#        'Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)',
#        'Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)',
#        'Income Rank (where 1 is most deprived)',
#        'Income Decile (where 1 is most deprived 10% of LSOAs)',
#        'Employment Rank (where 1 is most deprived)',
#        'Employment Decile (where 1 is most deprived 10% of LSOAs)',
#        'Education, Skills and Training Rank (where 1 is most deprived)',
#        'Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)',
#        'Health Deprivation and Disability Rank (where 1 is most deprived)',
#        'Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)',
#        'Crime Rank (where 1 is most deprived)',
#        'Crime Decile (where 1 is most deprived 10% of LSOAs)',
#        'Barriers to Housing and Services Rank (where 1 is most deprived)',
#        'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)',
#        'Living Environment Rank (where 1 is most deprived)',
#        'Living Environment Decile (where 1 is most deprived 10% of LSOAs)'],
#       dtype='object')

# %% [markdown]
# # STEP 6- reading inthe all_birmingham.csv from the file path

# %%
import os, glob #step 1
import pandas as pd #step2

path = 'C:/Users/Hi/Desktop/PYTHON/Big Data/Birmingham'
#The next code: *.csv match only files: that ends with file extension

fromfolder = glob.glob(os.path.join(path, "*.csv"))#step 2:match CSV files by pattern

#The final step is to load all selected files into a single
#DataFrame and converted it back to csv if needed:

birmighamfiles = (pd.read_csv(f, sep=',') for f in fromfolder)# read the
birmighamfiles
# Out:
# <generator object <genexpr> at 0x000002C13EE19890>

# %% [markdown]
# # Time to concat this variable called birmigham

# %%
df_merge = pd.concat(birmighamfiles, ignore_index=True)#combile
df_merge.head(2)
# Out:
#   Crime ID    Month               Reported by              Falls within  \
# 0      NaN  2015-01  British Transport Police  British Transport Police
# 1      NaN  2015-01  British Transport Police  British Transport Police
#
#    Longitude  Latitude                    Location  LSOA code  LSOA name  \
# 0  -0.271604   50.8344  On or near Shoreham-By-Sea  E01031365  Adur 002D
# 1  -0.271604   50.8344  On or near Shoreham-By-Sea  E01031365  Adur 002D
#
#     Crime type Last outcome category  Context
# 0  Other theft                   NaN      NaN
# 1  Other theft                   NaN      NaN

# %% [markdown]
# # copy from df_mergee to a new name all_ birmingham

# %%
all_birmingham = df_merge
#Transfer variable name to a new simple name all_birmingham

# %% [markdown]
# # Export To CSV

# %%
df_merge.to_csv("all_birmingham.csv", index_label= False, index= False)
#if you wish to export to csv i can do that with this line

# %% [markdown]
# # import  the exported file again

# %%
all_birmingham = pd.read_csv("all_birmingham.csv")
#read all_birmingham.csv into jupyter notebook
all_birmingham.head(3)
# Out:
#   Crime ID    Month               Reported by              Falls within  \
# 0      NaN  2015-01  British Transport Police  British Transport Police
# 1      NaN  2015-01  British Transport Police  British Transport Police
# 2      NaN  2015-01  British Transport Police  British Transport Police
#
#    Longitude  Latitude                    Location  LSOA code  LSOA name  \
# 0  -0.271604   50.8344  On or near Shoreham-By-Sea  E01031365  Adur 002D
# 1  -0.271604   50.8344  On or near Shoreham-By-Sea  E01031365  Adur 002D
# 2  -0.271604   50.8344  On or near Shoreham-By-Sea  E01031365  Adur 002D
#
#               Crime type Last outcome category  Context
# 0            Other theft                   NaN      NaN
# 1            Other theft                   NaN      NaN
# 2  Theft from the person                   NaN      NaN

# %% [markdown]
# # Step 7- Taking a look at all_birmingham

# %%
all_birmingham.columns
# Out:
# Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category', 'Context'],
#       dtype='object')

# %% [markdown]
# # Step 8- Get rid of useless columns using del

# %%
del all_birmingham['Reported by']
del all_birmingham['Crime ID']
del all_birmingham['Location']

# %% [markdown]
# # Step- 9 Checking the columns again after we had deleted

# %%
all_birmingham.columns
# Out:
# Index(['Month', 'Falls within', 'Longitude', 'Latitude', 'LSOA code',
#        'LSOA name', 'Crime type', 'Last outcome category', 'Context'],
#       dtype='object')

# %% [markdown]
# # Step 10- Taking a quick look at the Data shape like how many rows and columns do we have

# %%
all_birmingham.shape
# Out:
# (1601661, 9)

# %% [markdown]
# # step-11 Data cleaning:Renaming Month to Date

# %%
all_birmingham.head(2)
# Out:
#      Month              Falls within  Longitude  Latitude  LSOA code  \
# 0  2015-01  British Transport Police  -0.271604   50.8344  E01031365
# 1  2015-01  British Transport Police  -0.271604   50.8344  E01031365
#
#    LSOA name   Crime type Last outcome category  Context
# 0  Adur 002D  Other theft                   NaN      NaN
# 1  Adur 002D  Other theft                   NaN      NaN

# %%
all_birmingham = all_birmingham.rename(columns ={'Month':'Date'})
all_birmingham.columns#check columns again
# Out:
# Index(['Date', 'Falls within', 'Longitude', 'Latitude', 'LSOA code',
#        'LSOA name', 'Crime type', 'Last outcome category', 'Context'],
#       dtype='object')

# %% [markdown]
# # Step-12 i think its time to split Date col into Multiple columns of 'Year', 'Months'

# %%
all_birmingham[['Years', 'Months']] = all_birmingham['Date'].str.split('-',expand=True)
all_birmingham.head(2)
# Out:
#       Date              Falls within  Longitude  Latitude  LSOA code  \
# 0  2015-01  British Transport Police  -0.271604   50.8344  E01031365
# 1  2015-01  British Transport Police  -0.271604   50.8344  E01031365
#
#    LSOA name   Crime type Last outcome category  Context Years Months
# 0  Adur 002D  Other theft                   NaN      NaN  2015     01
# 1  Adur 002D  Other theft                   NaN      NaN  2015     01

# %% [markdown]
# # Step 13- checking if the Date column is  a pandas recognize datetime64 Format, if it is
# an object, then we need to change to Datetime

# %%
all_birmingham.dtypes #data type function
# Out:
# Date                      object
# Falls within              object
# Longitude                float64
# Latitude                 float64
# LSOA code                 object
# LSOA name                 object
# Crime type                object
# Last outcome category     object
# Context                  float64
# Years                     object
# Months                    object
# dtype: object

# %% [markdown]
# # step 14- change to Datetime: From object data type to pandas datetime

# %%
all_birmingham.Date = pd.to_datetime(all_birmingham.Date)
all_birmingham.dtypes#to confirm once  more
# Out:
# Date                     datetime64[ns]
# Falls within                     object
# Longitude                       float64
# Latitude                        float64
# LSOA code                        object
# LSOA name                        object
# Crime type                       object
# Last outcome category            object
# Context                         float64
# Years                            object
# Months                           object
# dtype: object

# %%
all_birmingham.head(2)
# Out:
#         Date              Falls within  Longitude  Latitude  LSOA code  \
# 0 2015-01-01  British Transport Police  -0.271604   50.8344  E01031365
# 1 2015-01-01  British Transport Police  -0.271604   50.8344  E01031365
#
#    LSOA name   Crime type Last outcome category  Context Years Months
# 0  Adur 002D  Other theft                   NaN      NaN  2015     01
# 1  Adur 002D  Other theft                   NaN      NaN  2015     01

# %% [markdown]
# # step 15- lets create a new column called Qtrs from the Birmingham dataframe using pandas dt.quater

# %%
all_birmingham['Qtrs'] = all_birmingham['Date'].dt.quarter#dt means datetime
#creating a new col [Qtrs] from ['Date'] using datetime function(dt.quarter)

# %%
all_birmingham.head(2)
# Out:
#         Date              Falls within  Longitude  Latitude  LSOA code  \
# 0 2015-01-01  British Transport Police  -0.271604   50.8344  E01031365
# 1 2015-01-01  British Transport Police  -0.271604   50.8344  E01031365
#
#    LSOA name   Crime type Last outcome category  Context Years Months  Qtrs
# 0  Adur 002D  Other theft                   NaN      NaN  2015     01     1
# 1  Adur 002D  Other theft                   NaN      NaN  2015     01     1

# %% [markdown]
# # step 16- check cols again for any changes

# %%
all_birmingham.columns
# Out:
# Index(['Date', 'Falls within', 'Longitude', 'Latitude', 'LSOA code',
#        'LSOA name', 'Crime type', 'Last outcome category', 'Context', 'Years',
#        'Months', 'Qtrs'],
#       dtype='object')

# %% [markdown]
# # step 17- How many unique Quarters do we have inside the Qtrs

# %%
all_birmingham['Qtrs'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %% [markdown]
# # step 18- Working on selectionbirmingham Dataframe now
# by sub -selecting the colums that i actually need and storing them into new Variable called selected
# birmingham

# %%
all_birmingham.columns
# Out:
# Index(['Date', 'Falls within', 'Longitude', 'Latitude', 'LSOA code',
#        'LSOA name', 'Crime type', 'Last outcome category', 'Context', 'Years',
#        'Months', 'Qtrs'],
#       dtype='object')

# %%
selectedbirmingham = all_birmingham[['LSOA code','LSOA name','Qtrs']]#i pick only 3 columns
selectedbirmingham.head()
# Out:
#    LSOA code  LSOA name  Qtrs
# 0  E01031365  Adur 002D     1
# 1  E01031365  Adur 002D     1
# 2  E01031365  Adur 002D     1
# 3  E01031365  Adur 002D     1
# 4  E01031342  Adur 008B     1

# %%
selectedbirmingham.head(10)
# Out:
#    LSOA code       LSOA name  Qtrs
# 0  E01031365       Adur 002D     1
# 1  E01031365       Adur 002D     1
# 2  E01031365       Adur 002D     1
# 3  E01031365       Adur 002D     1
# 4  E01031342       Adur 008B     1
# 5  E01031342       Adur 008B     1
# 6  E01019114  Allerdale 004D     1
# 7  E01019114  Allerdale 004D     1
# 8  E01031393       Arun 003A     1
# 9  E01031393       Arun 003A     1

# %% [markdown]
# # Step 19- : check columns again

# %%
Domains_of_Deprivation.columns
# Out:
# Index(['LSOA code (2011)', 'LSOA name (2011)',
#        'Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)',
#        'Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)',
#        'Income Rank (where 1 is most deprived)',
#        'Income Decile (where 1 is most deprived 10% of LSOAs)',
#        'Employment Rank (where 1 is most deprived)',
#        'Employment Decile (where 1 is most deprived 10% of LSOAs)',
#        'Education, Skills and Training Rank (where 1 is most deprived)',
#        'Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)',
#        'Health Deprivation and Disability Rank (where 1 is most deprived)',
#        'Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)',
#        'Crime Rank (where 1 is most deprived)',
#        'Crime Decile (where 1 is most deprived 10% of LSOAs)',
#        'Barriers to Housing and Services Rank (where 1 is most deprived)',
#        'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)',
#        'Living Environment Rank (where 1 is most deprived)',
#        'Living Environment Decile (where 1 is most deprived 10% of LSOAs)'],
#       dtype='object')

# %% [markdown]
# # step 20 : do i need to remove some columns that arent important using del function? Yes

# %%
del Domains_of_Deprivation[ 'Living Environment Rank (where 1 is most deprived)']
del Domains_of_Deprivation[ 'Living Environment Decile (where 1 is most deprived 10% of LSOAs)']

# %% [markdown]
# # Step 21- check the columns again

# %%
Domains_of_Deprivation.columns
# Out:
# Index(['LSOA code (2011)', 'LSOA name (2011)',
#        'Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)',
#        'Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)',
#        'Income Rank (where 1 is most deprived)',
#        'Income Decile (where 1 is most deprived 10% of LSOAs)',
#        'Employment Rank (where 1 is most deprived)',
#        'Employment Decile (where 1 is most deprived 10% of LSOAs)',
#        'Education, Skills and Training Rank (where 1 is most deprived)',
#        'Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)',
#        'Health Deprivation and Disability Rank (where 1 is most deprived)',
#        'Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)',
#        'Crime Rank (where 1 is most deprived)',
#        'Crime Decile (where 1 is most deprived 10% of LSOAs)',
#        'Barriers to Housing and Services Rank (where 1 is most deprived)',
#        'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)'],
#       dtype='object')

# %% [markdown]
# # Step 22: Renaming LSOA code (2011) to LSOA  to LSOA name & LSOA name(2011) to LSOA name

# %%
Domains_of_Deprivation = Domains_of_Deprivation.rename(columns = {'LSOA code (2011)':'LSOA code'})

Domains_of_Deprivation =  Domains_of_Deprivation.rename(columns ={'LSOA name (2011)':'LSOA name'})

# %% [markdown]
# # step 23 - confirm if column name has change

# %%
Domains_of_Deprivation.columns
# Out:
# Index(['LSOA code', 'LSOA name',
#        'Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)',
#        'Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)',
#        'Income Rank (where 1 is most deprived)',
#        'Income Decile (where 1 is most deprived 10% of LSOAs)',
#        'Employment Rank (where 1 is most deprived)',
#        'Employment Decile (where 1 is most deprived 10% of LSOAs)',
#        'Education, Skills and Training Rank (where 1 is most deprived)',
#        'Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)',
#        'Health Deprivation and Disability Rank (where 1 is most deprived)',
#        'Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)',
#        'Crime Rank (where 1 is most deprived)',
#        'Crime Decile (where 1 is most deprived 10% of LSOAs)',
#        'Barriers to Housing and Services Rank (where 1 is most deprived)',
#        'Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)'],
#       dtype='object')

# %% [markdown]
# # Step 24: still on ETL process- Here i want  to copy from Domains_of_Deprivation and save it on copy_Domains_of_Deprivation

# %% [markdown]
# copy_Domains_of_deprivation = Domains_of_Deprivation

# %% [markdown]
# # STEP- 25 Unpivoting using pandas melt function which is quite crucialUnpivot data- i need to manipulate the social Deprivation table or Dataframe by unpivoting the columns into rowsmeaning if the some columns were on the column level, ineed to transform them into rows so as to be able to perform some intelligent ETL process like merging

# %%
#first thing, so I will create a new variable ----> UnpivotedDomains_of_Deprivation

#after that I will tell python to keep the following columns as columns as it were ---> LSOA code', 'LSOA name(id_vars)'

#Then I will tell python to create a new column called category ----> var_name = 'category',
#and their row valuename should be --> value_name='value')

UnpivotedDomains_of_Deprivation = pd.melt(copy_Domains_of_deprivation, id_vars = ['LSOA code', 'LSOA name'], var_name= 'category', value_name='value')

# %%
UnpivotedDomains_of_Deprivation.head()
# Out:
#    LSOA code                  LSOA name  \
# 0  E01000001        City of London 001A
# 1  E01000002        City of London 001B
# 2  E01000003        City of London 001C
# 3  E01000005        City of London 001E
# 4  E01000006  Barking and Dagenham 016A
#
#                                             category  value
# 0  Index of Multiple Deprivation (IMD) Rank (wher...  29199
# 1  Index of Multiple Deprivation (IMD) Rank (wher...  30379
# 2  Index of Multiple Deprivation (IMD) Rank (wher...  14915
# 3  Index of Multiple Deprivation (IMD) Rank (wher...   8678
# 4  Index of Multiple Deprivation (IMD) Rank (wher...  14486

# %%
results = UnpivotedDomains_of_Deprivation.merge(selectedbirmingham, on = 'LSOA name')

# %%
results.head()
# Out:
#   LSOA code_x            LSOA name  \
# 0   E01000001  City of London 001A
# 1   E01000001  City of London 001A
# 2   E01000001  City of London 001A
# 3   E01000001  City of London 001A
# 4   E01000001  City of London 001A
#
#                                             category  value LSOA code_y  Qtrs
# 0  Index of Multiple Deprivation (IMD) Rank (wher...  29199   E01000001     1
# 1  Index of Multiple Deprivation (IMD) Rank (wher...  29199   E01000001     1
# 2  Index of Multiple Deprivation (IMD) Rank (wher...  29199   E01000001     2
# 3  Index of Multiple Deprivation (IMD) Rank (wher...  29199   E01000001     2
# 4  Index of Multiple Deprivation (IMD) Rank (wher...  29199   E01000001     2

# %%
del results ['LSOA code_y']

# %%
results.head()
# Out:
#   LSOA code_x            LSOA name  \
# 0   E01000001  City of London 001A
# 1   E01000001  City of London 001A
# 2   E01000001  City of London 001A
# 3   E01000001  City of London 001A
# 4   E01000001  City of London 001A
#
#                                             category  value  Qtrs
# 0  Index of Multiple Deprivation (IMD) Rank (wher...  29199     1
# 1  Index of Multiple Deprivation (IMD) Rank (wher...  29199     1
# 2  Index of Multiple Deprivation (IMD) Rank (wher...  29199     2
# 3  Index of Multiple Deprivation (IMD) Rank (wher...  29199     2
# 4  Index of Multiple Deprivation (IMD) Rank (wher...  29199     2

# %%
SocialDeprivation = results #copy from results to final clean Data

# %% [markdown]
# # STEP 28 - we can change the column name from category to social Deprivation¶1

# %%
SocialDeprivation['Qtrs'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
SocialDeprivation.to_csv('SocialDeprivation By Qtrs.csv')

# %%
copy_Domains_of_deprivation.head(2)
# Out:
#    LSOA code            LSOA name  \
# 0  E01000001  City of London 001A
# 1  E01000002  City of London 001B
#
#    Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)  \
# 0                                              29199
# 1                                              30379
#
#    Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                  9
# 1                                                 10
#
#    Income Rank (where 1 is most deprived)  \
# 0                                   32831
# 1                                   29901
#
#    Income Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
#
#    Employment Rank (where 1 is most deprived)  \
# 0                                       32742
# 1                                       31190
#
#    Employment Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
#
#    Education, Skills and Training Rank (where 1 is most deprived)  \
# 0                                              32842
# 1                                              32832
#
#    Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
#
#    Health Deprivation and Disability Rank (where 1 is most deprived)  \
# 0                                              32113
# 1                                              29705
#
#    Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
#
#    Crime Rank (where 1 is most deprived)  \
# 0                                  32662
# 1                                  32789
#
#    Crime Decile (where 1 is most deprived 10% of LSOAs)  \
# 0                                                 10
# 1                                                 10
#
#    Barriers to Housing and Services Rank (where 1 is most deprived)  \
# 0                                               7319
# 1                                              11707
#
#    Barriers to Housing and Services Decile (where 1 is most deprived 10% of LSOAs)
# 0                                                  3
# 1                                                  4

# %%
import sidetable

# %% [markdown]
# https://github.com/vinta/awesome-python/blob/master/README.md

# %%
copy_Domains_of_deprivation.stb.missing(style=True)
#how many missing values if at all there is
# Out:
# <style  type="text/css" >
# </style><table id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >missing</th>        <th class="col_heading level0 col1" >total</th>        <th class="col_heading level0 col2" >percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row0" class="row_heading level0 row0" >LSOA code</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow0_col1" class="data row0 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow0_col2" class="data row0 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row1" class="row_heading level0 row1" >LSOA name</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow1_col1" class="data row1 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow1_col2" class="data row1 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row2" class="row_heading level0 row2" >Index of Multiple Deprivation (IMD) Rank (where 1 is most deprived)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow2_col0" class="data row2 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow2_col1" class="data row2 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow2_col2" class="data row2 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row3" class="row_heading level0 row3" >Index of Multiple Deprivation (IMD) Decile (where 1 is most deprived 10% of LSOAs)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow3_col0" class="data row3 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow3_col1" class="data row3 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow3_col2" class="data row3 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row4" class="row_heading level0 row4" >Income Rank (where 1 is most deprived)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow4_col1" class="data row4 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow4_col2" class="data row4 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row5" class="row_heading level0 row5" >Income Decile (where 1 is most deprived 10% of LSOAs)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow5_col1" class="data row5 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow5_col2" class="data row5 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row6" class="row_heading level0 row6" >Employment Rank (where 1 is most deprived)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow6_col1" class="data row6 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow6_col2" class="data row6 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row7" class="row_heading level0 row7" >Employment Decile (where 1 is most deprived 10% of LSOAs)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow7_col0" class="data row7 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow7_col1" class="data row7 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow7_col2" class="data row7 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row8" class="row_heading level0 row8" >Education, Skills and Training Rank (where 1 is most deprived)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow8_col0" class="data row8 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow8_col1" class="data row8 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow8_col2" class="data row8 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row9" class="row_heading level0 row9" >Education, Skills and Training Decile (where 1 is most deprived 10% of LSOAs)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow9_col0" class="data row9 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow9_col1" class="data row9 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow9_col2" class="data row9 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row10" class="row_heading level0 row10" >Health Deprivation and Disability Rank (where 1 is most deprived)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow10_col0" class="data row10 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow10_col1" class="data row10 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow10_col2" class="data row10 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row11" class="row_heading level0 row11" >Health Deprivation and Disability Decile (where 1 is most deprived 10% of LSOAs)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow11_col0" class="data row11 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow11_col1" class="data row11 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow11_col2" class="data row11 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row12" class="row_heading level0 row12" >Crime Rank (where 1 is most deprived)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow12_col0" class="data row12 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow12_col1" class="data row12 col1" >32,844</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow12_col2" class="data row12 col2" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51flevel0_row13" class="row_heading level0 row13" >Crime Decile (where 1 is most deprived 10% of LSOAs)</th>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow13_col0" class="data row13 col0" >0</td>
#                         <td id="T_abf0fb81_031e_11ec_a23f_3ca82a84c51frow13_col1" class="data row13 col1" >32,844</td>

# %%
SocialDeprivation.columns
# Out:
# Index(['LSOA code_x', 'LSOA name', 'category', 'value', 'Qtrs'], dtype='object')

# %%
SocialDeprivation.stb.freq(['Qtrs', 'category', 'value'])
# Out:
#         Qtrs                                           category  value  \
# 0          3  Income Decile (where 1 is most deprived 10% of...      1
# 1          4  Income Decile (where 1 is most deprived 10% of...      1
# 2          2  Income Decile (where 1 is most deprived 10% of...      1
# 3          3  Index of Multiple Deprivation (IMD) Decile (wh...      1
# 4          4  Index of Multiple Deprivation (IMD) Decile (wh...      1
# ...      ...                                                ...    ...
# 103694     1  Barriers to Housing and Services Rank (where 1...    257
# 103695     1  Barriers to Housing and Services Rank (where 1...    171
# 103696     1  Barriers to Housing and Services Rank (where 1...     86
# 103697     1  Barriers to Housing and Services Rank (where 1...      7
# 103698     1  Barriers to Housing and Services Rank (where 1...      5
#
#          count   percent  cumulative_count  cumulative_percent
# 0       135162  0.607148            135162            0.607148
# 1       131645  0.591350            266807            1.198497
# 2       131379  0.590155            398186            1.788652
# 3       129598  0.582154            527784            2.370806
# 4       126041  0.566176            653825            2.936983
# ...        ...       ...               ...                 ...
# 103694       1  0.000004          22261788           99.999982
# 103695       1  0.000004          22261789           99.999987
# 103696       1  0.000004          22261790           99.999991
# 103697       1  0.000004          22261791           99.999996
# 103698       1  0.000004          22261792          100.000000
#
# [103699 rows x 7 columns]

# %%
SocialDeprivation.stb.freq(['Qtrs', 'category'])
# Out:
#     Qtrs                                           category   count   percent  \
# 0      4  Index of Multiple Deprivation (IMD) Rank (wher...  409194  1.838100
# 1      4  Index of Multiple Deprivation (IMD) Decile (wh...  409194  1.838100
# 2      4             Income Rank (where 1 is most deprived)  409194  1.838100
# 3      4  Income Decile (where 1 is most deprived 10% of...  409194  1.838100
# 4      4  Health Deprivation and Disability Rank (where ...  409194  1.838100
# 5      4  Health Deprivation and Disability Decile (wher...  409194  1.838100
# 6      4         Employment Rank (where 1 is most deprived)  409194  1.838100
# 7      4  Employment Decile (where 1 is most deprived 10...  409194  1.838100
# 8      4  Education, Skills and Training Rank (where 1 i...  409194  1.838100
# 9      4  Education, Skills and Training Decile (where 1...  409194  1.838100
# 10     4              Crime Rank (where 1 is most deprived)  409194  1.838100
# 11     4  Crime Decile (where 1 is most deprived 10% of ...  409194  1.838100
# 12     4  Barriers to Housing and Services Rank (where 1...  409194  1.838100
# 13     4  Barriers to Housing and Services Decile (where...  409194  1.838100
# 14     3  Index of Multiple Deprivation (IMD) Rank (wher...  407576  1.830832
# 15     3  Index of Multiple Deprivation (IMD) Decile (wh...  407576  1.830832
# 16     3             Income Rank (where 1 is most deprived)  407576  1.830832
# 17     3  Income Decile (where 1 is most deprived 10% of...  407576  1.830832
# 18     3  Health Deprivation and Disability Rank (where ...  407576  1.830832
# 19     3  Health Deprivation and Disability Decile (wher...  407576  1.830832
# 20     3         Employment Rank (where 1 is most deprived)  407576  1.830832
# 21     3  Employment Decile (where 1 is most deprived 10...  407576  1.830832
# 22     3  Education, Skills and Training Rank (where 1 i...  407576  1.830832
# 23     3  Education, Skills and Training Decile (where 1...  407576  1.830832
# 24     3              Crime Rank (where 1 is most deprived)  407576  1.830832
# 25     3  Crime Decile (where 1 is most deprived 10% of ...  407576  1.830832
# 26     3  Barriers to Housing and Services Rank (where 1...  407576  1.830832
# 27     3  Barriers to Housing and Services Decile (where...  407576  1.830832
# 28     2  Index of Multiple Deprivation (IMD) Rank (wher...  397336  1.784834
# 29     2  Index of Multiple Deprivation (IMD) Decile (wh...  397336  1.784834
# 30     2             Income Rank (where 1 is most deprived)  397336  1.784834
# 31     2  Income Decile (where 1 is most deprived 10% of...  397336  1.784834
# 32     2  Health Deprivation and Disability Rank (where ...  397336  1.784834
# 33     2  Health Deprivation and Disability Decile (wher...  397336  1.784834
# 34     2         Employment Rank (where 1 is most deprived)  397336  1.784834
# 35     2  Employment Decile (where 1 is most deprived 10...  397336  1.784834
# 36     2  Education, Skills and Training Rank (where 1 i...  397336  1.784834
# 37     2  Education, Skills and Training Decile (where 1...  397336  1.784834
# 38     2              Crime Rank (where 1 is most deprived)  397336  1.784834
# 39     2  Crime Decile (where 1 is most deprived 10% of ...  397336  1.784834
# 40     2  Barriers to Housing and Services Rank (where 1...  397336  1.784834
# 41     2  Barriers to Housing and Services Decile (where...  397336  1.784834
# 42     1  Index of Multiple Deprivation (IMD) Rank (wher...  376022  1.689091
# 43     1  Index of Multiple Deprivation (IMD) Decile (wh...  376022  1.689091
# 44     1             Income Rank (where 1 is most deprived)  376022  1.689091
# 45     1  Income Decile (where 1 is most deprived 10% of...  376022  1.689091
# 46     1  Health Deprivation and Disability Rank (where ...  376022  1.689091
# 47     1  Health Deprivation and Disability Decile (wher...  376022  1.689091
# 48     1         Employment Rank (where 1 is most deprived)  376022  1.689091
# 49     1  Employment Decile (where 1 is most deprived 10...  376022  1.689091
# 50     1  Education, Skills and Training Rank (where 1 i...  376022  1.689091
# 51     1  Education, Skills and Training Decile (where 1...  376022  1.689091
# 52     1              Crime Rank (where 1 is most deprived)  376022  1.689091
# 53     1  Crime Decile (where 1 is most deprived 10% of ...  376022  1.689091
# 54     1  Barriers to Housing and Services Rank (where 1...  376022  1.689091
# 55     1  Barriers to Housing and Services Decile (where...  376022  1.689091
#
#     cumulative_count  cumulative_percent
# 0             409194            1.838100
# 1             818388            3.676200
# 2            1227582            5.514300
# 3            1636776            7.352400
# 4            2045970            9.190500
# 5            2455164           11.028600
# 6            2864358           12.866700
# 7            3273552           14.704800
# 8            3682746           16.542900
# 9            4091940           18.381000
# 10           4501134           20.219100
# 11           4910328           22.057200
# 12           5319522           23.895300
# 13           5728716           25.733400
# 14           6136292           27.564232
# 15           6543868           29.395064
# 16           6951444           31.225896
# 17           7359020           33.056728
# 18           7766596           34.887560
# 19           8174172           36.718392
# 20           8581748           38.549224
# 21           8989324           40.380056
# 22           9396900           42.210888
# 23           9804476           44.041720
# 24          10212052           45.872551
# 25          10619628           47.703383
# 26          11027204           49.534215
# 27          11434780           51.365047
# 28          11832116           53.149881
# 29          12229452           54.934715
# 30          12626788           56.719549
# 31          13024124           58.504383
# 32          13421460           60.289217
# 33          13818796           62.074050
# 34          14216132           63.858884
# 35          14613468           65.643718
# 36          15010804           67.428552
# 37          15408140           69.213386
# 38          15805476           70.998220
# 39          16202812           72.783054
# 40          16600148           74.567887
# 41          16997484           76.352721
# 42          17373506           78.041813
# 43          17749528           79.730904
# 44          18125550           81.419995
# 45          18501572           83.109087
# 46          18877594           84.798178
# 47          19253616           86.487269
# 48          19629638           88.176361
# 49          20005660           89.865452
# 50          20381682           91.554543
# 51          20757704           93.243635
# 52          21133726           94.932726
# 53          21509748           96.621817
# 54          21885770           98.310909
# 55          22261792          100.000000

# %%
df=pd.read_csv('http://bit.ly/HDSC-Dataset')
df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# 1      rockport total plant                coal       ton       10486945.0
# 2                    gorgas                coal       ton        2978683.0
# 3                     barry                coal       ton        3739484.0
# 4                 chickasaw                 gas       mcf          40533.0
# ...                     ...                 ...       ...              ...
# 29518    neil simpson ct #1                 gas       mcf          18799.0
# 29519  cheyenne prairie 58%                 gas       mcf         806730.0
# 29520     lange ct facility                 gas       mcf         104554.0
# 29521       wygen 3 bhp 52%                coal       ton         315945.0
# 29522       wygen 3 bhp 52%                 gas       mcf          17853.0
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0                   16.590                      18.59
# 1                   16.592                      18.58
# 2                   24.130                      39.72
# 3                   23.950                      47.21
# 4                    1.000                       2.77
# ...                    ...                        ...
# 29518                1.059                       4.78
# 29519                1.050                       3.65
# 29520                1.060                       4.77
# 29521               16.108                       3.06
# 29522                1.059                       0.00
#
#        fuel_cost_per_unit_delivered  fuel_cost_per_mmbtu
# 0                             18.53                1.121
# 1                             18.53                1.120
# 2                             38.12                1.650
# 3                             45.99                1.970
# 4                              2.77                2.570
# ...                             ...                  ...
# 29518                          4.78                9.030
# 29519                          3.65                6.950
# 29520                          4.77                8.990
# 29521                         14.76                1.110
# 29522                          0.00               11.680
#
# [29523 rows x 11 columns]

# %%
df.shape
# Out:
# (29523, 11)

# %%
df.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
del df['fuel_cost_per_mmbtu']

# %%
df.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered'],
#       dtype='object')

# %%
df.sumary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-8935040af497> in <module>
# ----> 1 df.sumary()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sumary'
